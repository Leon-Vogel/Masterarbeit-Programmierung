# %%
from _dir_init import *
import pandas as pd
import numpy as np
import os
import pickle
# from isri_simulation.isri_simulation import Log, Product, Simulation, Siminfo
from isri_optimizer.isri_metaheuristic_simple import fast_sim_diffsum, plan_by_due_date

# %%
with open(os.path.join(PROJECT_ROOT_DIR, "isri_optimizer", 'rl_swapagent', 'instance_15'), 'rb') as file:
    jobdata = pickle.load(file)
'''
Scheinbares Datenformat
dict mit 200 jobs
Key=Auftragsnummer?
Dann wieder dict mit keys
    1. times: Liste der Durations wie lange dieser job auf einer OP benötigt. 12 Einträge, da 12 OPS
    2. due_date: in Sek
'''
len(jobdata[0])
# type(data[0])
# len()
jobdata
# Out:
# [{23039837706: {'times': [101.52,
#     93.48,
#     72.78,
#     0.0,
#     74.16000000000001,
#     92.10000000000001,
#     68.94000000000001,
#     75.0,
#     77.22000000000001,
#     98.58,
#     78.89999999999999,
#     131.27999999999997],
#    'due_date': 3600.0},
#   23039837710: {'times': [101.52,
#     93.48,
#     72.78,
#     0.0,
#     74.16000000000001,
#     129.47999999999996,
#     98.64000000000001,
#     106.68,
#     77.22000000000001,
#     98.58,
#     88.07999999999998,
#     131.27999999999997],
#    'due_date': 3780.0},
#   23039837713: {'times': [110.69999999999999,
#     316.44000000000005,
#     72.78,
#     0.0,
#     18.36,
#     92.10000000000001,
#     68.94000000000001,
#     75.0,
#     77.22000000000001,
#     98.58,
#     88.61999999999999,
#     131.27999999999997],
#    'due_date': 3960.0},
#   23039837712: {'times': [110.69999999999999,
#     316.44000000000005,
#     72.78,
#     0.0,
#     18.36,
#     88.68,
#     68.94000000000001,
# ...

# %%
n_jobs = len(jobdata)
n_machines = 12
jobs = jobdata[0]
x = np.array(list(jobdata[0].keys())) # Genom, Reihenfolge der Jobs. Permutation der Keys in Jobdata; np.array [23039847988, 23039847987...]
    # Verwende jpl Jobs pro Linie und den Rest in den Backlog. Es gibt auch die Funktion split_lines..., die das übernimmt
jpl = 48
conv_speed = 208  # Zeit in s pro Arbeitsplatz
n_lines = 1

diffsum, tardiness = fast_sim_diffsum(x, jobs, jpl, conv_speed, n_machines, n_lines=n_lines)  # diffsum= Summe der Differenzen aller Zeiten von benachbarten Jobs. Ist negativ, weil pymoo nur minimieren kann und wir diese Zahl jedoch maximieren möchten
diffsum, tardiness
# Out:
# (-54.55999999999998, 49.90455570854984)

# %%
'''
A. Nutzung von fast_sim_diffsum:
    1. Was bedeuten die Argumente ind, jobs, jpl, conv_speed und windows_size?
    2. Wie extrahiere ich diese Argumente aus jobdata?
    3. Ist fast_sim_diffsum ein vollwertiger Ersatz für die Simulation oder muss man die Simulation trotzdem mitlaufen lassen?
    4. Was macht fast_sim_diffsum?
B. Gibt es eine Funktion, die zwei Jobs miteinander swapt? -> flip_positions_mutation(), macht es aber random
'''

# %%
plan_by_due_date(jobs=jobdata[0], jpl=48, n_lines=1)
# Out:
# [23039837706,
#  23039837710,
#  23039837713,
#  23039837712,
#  23039837716,
#  23039837719,
#  23039837722,
#  23039837721,
#  23039837732,
#  23039837731,
#  23039837734,
#  23039837737,
#  23039837738,
#  23039837741,
#  23039837740,
#  23039837743,
#  23039837747,
#  23039837749,
#  23039837750,
#  23039837753,
#  23039837755,
#  23039837758,
#  23039837761,
#  23039837760,
#  23039837763,
#  23039837764,
#  23039837767,
#  23039837770,
#  23039837773,
#  23039837776,
#  23039837778,
#  23039837779,
#  23039837781,
#  23039837785,
#  23039837784,
#  23039837788,
#  23039837791,
#  23039837793,
#  23039837797,
#  23039837796,
#  23039837800,
#  23039837803,
#  23039837805,
#  23039837806,
#  23039837818,
#  23039837821,
#  23039837822,
#  23039837825,
#  23039837828,
#  23039837830,
#  23039837834,
#  23039837833,
#  23039837837,
#  23039837840,
#  23039837842,
#  23039837846,
#  23039837845,
#  23039837849,
#  23039837851,
#  23039837852,
#  23039837855,
#  23039837857,
# ...

# %%
jobdata[0]
# Out:
# {23039837706: {'times': [101.52,
#    93.48,
#    72.78,
#    0.0,
#    74.16000000000001,
#    92.10000000000001,
#    68.94000000000001,
#    75.0,
#    77.22000000000001,
#    98.58,
#    78.89999999999999,
#    131.27999999999997],
#   'due_date': 3600.0},
#  23039837710: {'times': [101.52,
#    93.48,
#    72.78,
#    0.0,
#    74.16000000000001,
#    129.47999999999996,
#    98.64000000000001,
#    106.68,
#    77.22000000000001,
#    98.58,
#    88.07999999999998,
#    131.27999999999997],
#   'due_date': 3780.0},
#  23039837713: {'times': [110.69999999999999,
#    316.44000000000005,
#    72.78,
#    0.0,
#    18.36,
#    92.10000000000001,
#    68.94000000000001,
#    75.0,
#    77.22000000000001,
#    98.58,
#    88.61999999999999,
#    131.27999999999997],
#   'due_date': 3960.0},
#  23039837712: {'times': [110.69999999999999,
#    316.44000000000005,
#    72.78,
#    0.0,
#    18.36,
#    88.68,
#    68.94000000000001,
#    80.76,
#    104.58000000000001,
#    98.58,
# ...

# %% [markdown]
# ### Create Simple Test Data to Debug env

# %%
due_dates = [832,1040,1248,1456,1664,1872,2080,2288,2496,2704]
times1 = [2, 2, 2, 2]
times2 = [3, 3, 3, 3]
jobdata = {
    job_id: {"times": times1 if job_id%2==0 else times2, "due_date": due_date} for job_id, due_date in zip(range(1000, 1010), due_dates) # range(10, 110, 10))
}

with open(os.path.join(r'C:\Projekte\SUPPORT\Software\project_support\src\executable', "isri_optimizer", 'rl_swapagent', 'instance_easy'), "wb") as file:
    pickle.dump(jobdata, file)
jobdata
# Out:
# {1000: {'times': [2, 2, 2, 2], 'due_date': 832},
#  1001: {'times': [3, 3, 3, 3], 'due_date': 1040},
#  1002: {'times': [2, 2, 2, 2], 'due_date': 1248},
#  1003: {'times': [3, 3, 3, 3], 'due_date': 1456},
#  1004: {'times': [2, 2, 2, 2], 'due_date': 1664},
#  1005: {'times': [3, 3, 3, 3], 'due_date': 1872},
#  1006: {'times': [2, 2, 2, 2], 'due_date': 2080},
#  1007: {'times': [3, 3, 3, 3], 'due_date': 2288},
#  1008: {'times': [2, 2, 2, 2], 'due_date': 2496},
#  1009: {'times': [3, 3, 3, 3], 'due_date': 2704}}
